# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("drinksbycountry.csv")
data.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     193 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
data.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
data.isna().sum()
# Out:
# country                         0
# beer_servings                   0
# spirit_servings                 0
# wine_servings                   0
# total_litres_of_pure_alcohol    0
# continent                       0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")
# %matplotlib inline

# %%
sns.pairplot(data,hue="continent",height=3, aspect=1)

# %%
sns.pairplot(data, hue="continent", height=3, diag_kind="hist")

# %%
data.hist(edgecolor="black", linewidth=1.2, figsize=(12,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000022B81F1F3D0>,
# ...
#       dtype=object)

# %%
plt.figure(figsize=(22,14))

plt.subplot(2,2,1)
sns.violinplot(x="continent", y="beer_servings", data=data)

plt.subplot(2,2,2)
sns.violinplot(x="continent", y="spirit_servings", data=data)

plt.subplot(2,2,3)
sns.violinplot(x="continent", y="wine_servings", data=data)

plt.subplot(2,2,4)
sns.violinplot(x="continent", y="total_litres_of_pure_alcohol", data=data)

# %%
data.boxplot(by="continent", figsize=(12,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000022B85FE6220>,
# ...
#       dtype=object)

# %%
pd.plotting.scatter_matrix(data, figsize=(12,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000022B86CD57C0>,
# ...
#       dtype=object)

# %%
sns.pairplot(data)

# %%
plt.figure(figsize=(12,8))

sns.heatmap(data.corr(), linewidths=1, annot=True , linecolor="gree")
